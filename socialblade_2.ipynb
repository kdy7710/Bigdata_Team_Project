# %%
from bs4 import BeautifulSoup
from selenium import webdriver
url = 'https://socialblade.com/youtube/channel/UCbFzvzDu17eDZ3RIeaLRswQ/monthly'
driver = webdriver.Chrome('chromedriver')
driver.get(url)

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
test = soup.find_all('script', {'type': 'text/javascript'})
for i, name in enumerate(test):
    print(i,name)
# Out:
# 0 <script async="" src="https://www.gstatic.com/recaptcha/releases/wk6lx42JIeYmEAQSHndnyT8Q/recaptcha__ko.js" type="text/javascript"></script>
# 1 <script async="" src="https://www.gstatic.com/recaptcha/releases/wk6lx42JIeYmEAQSHndnyT8Q/recaptcha__ko.js" type="text/javascript"></script>
# 2 <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# 3 <script type="text/javascript">var beforeload = (new Date()).getTime()</script>
# 4 <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js" type="text/javascript"></script>
# 5 <script src="/js/cookie.js?version=9001.3212362854" type="text/javascript"></script>
# 6 <script src="//cdnjs.cloudflare.com/ajax/libs/dygraph/1.0.1/dygraph-combined.js" type="text/javascript"></script>
# 7 <script async="" id="factorem" src="//cdm.cursecdn.com/js/socialblade/cdmfactorem_min.js?misc=1588757278890" type="text/javascript"></script>
# ...

# %%
#유튜브 이름
indice=[i for i,name in enumerate(str(test[10])) if name == 'series']
print(indice)

print(obj.index(re.findall(series,obj)[2]))
youtube_name = 'UCbFzvzDu17eDZ3RIeaLRswQ'
start_n=obj.index("series: [")+124
end_n =obj.index("navigation: { menuItemStyle: { fontSize: '9px' } }")
a = obj[start_n:end_n-19]
a.split('],[')
# Out:
# []
# 2844
# ['1588219200000,50000',
#  '1585627200000,30000',
#  '1582952400000,60000',
#  '1580446800000,80000',
#  '1577768400000,70000',
#  '1575090000000,10000',
#  '1572494400000,10000',
#  '1569816000000,27521',
#  '1567224000000,41755',
#  '1564545600000,-18668',
#  '1561867200000,-14070',
#  '1559275200000,26801',
#  '1556596800000,26072',
#  '1554004800000,21347',
#  '1551330000000,25517',
#  '1548910800000,52623',
#  '1546232400000,66377',
#  '1543554000000,70711',
#  '1540958400000,56763',
#  '1538280000000,74771',
#  '1535688000000,85823',
#  '1533009600000,77978',
#  '1530331200000,190317',
#  '1527739200000,39174',
#  '1525060800000,30019',
#  '1522468800000,39635',
#  '1519794000000,41300',
#  '1517374800000,20093',
#  '1514696400000,16363',
#  '1512018000000,12290',
#  '1509422400000,14679',
#  '1506744000000,13173',
#  '1504152000000,18075',
#  '1501473600000,17721',
#  '1498795200000,13651']

# %%
import json
json.loads(a)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-52-a762428118e6> in <module>
#       1 import json
# ----> 2 json.loads(a)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 14 (char 13)
