# %%
from Naver_Api.naver_api import search
from Text_Mining import SetKorean


naverapi = search('트렌드 위드 미', startdate='2019-04-25' ,enddate= '2019-05-15')

naverapi.plot()

# %%
import pandas as pd
df = pd.read_excel('C:/Users/tjoeun/Downloads/7. 데이터 활용 매뉴얼 - 방송정보메타데이타샘플.xls')
# 사용할 컬럼만 추출 
df2 = df.loc[:,['프로그램','방송일','상품명','품번']]
df2
# Out:
#          프로그램         방송일                   상품명              품번
# 0    트렌드 위드 미  2019-05-01        글리셜 미셀라 클렌징 워터  글리셜 미셀라 클렌징 워터
# 1    트렌드 위드 미  2019-05-01          킵쿨 수드 대나무 세럼    킵쿨 수드 대나무 세럼
# 2    트렌드 위드 미  2019-05-01        핑크터치 올인원 톤업 크림  핑크터치 올인원 톤업 크림
# 3    트렌드 위드 미  2019-05-01          리쥬브네이션 플레게 젤    리쥬브네이션 플레게 젤
# 4    트렌드 위드 미  2019-05-01           풀커버 골드 에어쿠션     풀커버 골드 에어쿠션
# ..        ...         ...                   ...             ...
# 495       빅이슈  2019-05-02                데님 반바지      C192PSA435
# 496       빅이슈  2019-05-02          로고프린팅 루즈핏티셔츠      C192PSM032
# 497       빅이슈  2019-05-02  2019 S/S 소매 레터링 더블재킷      C192MSF035
# 498  팔로우 미 11  2019-05-02                기본핏자켓         JTJK326A
# 499     밥블레스유  2019-05-02      리잘록 레터링포인트 배색가디건      C191KSL003
#
# [500 rows x 4 columns]

# %% [markdown]
# # PPL 효과 없는 예제

# %%
plt.plot(naverapi)
plt.scatter('2019-05-01', int(naverapi.loc['2019-05-01']), c='r',label='방송날짜')
plt.plot(naverapi,'b',label='네이버 api 키워드 검색비율')
plt.title('트렌드위드미 8회차 핑크터치 올인원 톤업 크림')
plt.legend(loc='upper left')
plt.show()

# %%
from Naver_Api.naver_api import search
from Text_Mining import SetKorean
api = search('리쥬브네이션 플레게 젤', startdate='2019-04-01' ,enddate= '2019-06-01')
api.plot()
from matplotlib import pyplot as plt
plt.plot(api,'b')
plt.scatter('2019-05-01',int(api.loc['2019-05-01']), c='r',label='방송날짜')

# %%
def draw_ppl(program, broadcast_date, ppl_item):
    """
    params:
    프로그램명, 방송일자, ppl 상품명 

    output:
    키워드 네이버 API 검색 비율 방송날짜 가진 그래프 
    """
    from Naver_Api.naver_api import search
    from Text_Mining import SetKorean
    from matplotlib import pyplot as plt
    naverapi = search(ppl_item, startdate='2018-12-01' ,enddate= '2019-11-01')
    print('naverapi ok')
    plt.plot(naverapi)
    plt.scatter(broadcast_date, int(naverapi.loc[broadcast_date]), c='r',label='방송날짜')
    
    plt.plot(naverapi,'b',label='네이버 api 키워드 검색비율')
    plt.title('트렌드위드미 8회차 핑크터치 올인원 톤업 크림')
    plt.legend(loc='center left')
    plt.show()

# %%
draw_ppl('트렌드위드미', '2019-05-01' ,'리쥬브네이션 플레게 젤')
# Out:
# naverapi ok

# %%
from datetime import datetime
value = '2010-01-01'
date = datetime.strptime(value, '%Y-%m-%d')
print(date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-33b701acd884> in <module>
#       2 value = '2010-01-01'
#       3 date = datetime.strptime(value, '%Y-%m-%d')
# ----> 4 print(date-1)
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'int'

# %%
df = search('유재석 니트',startdate= '2020-02-05',enddate='2020-03-01')
# Out:
# missing_dates :[]

# %%
df = search('제너럴 아이디어',startdate= '2020-02-05',enddate='2020-03-01')
df.plot()
# Out:
# missing_dates :[]

# %%
from Naver_Api.naver_api import search
df = search('킵쿨 수드 대나무 세럼',startdate='2019-04-01',enddate='2019-05-31')
df.plot()
# Out:
# missing_dates :['20190402', '20190403', '20190407', '20190408', '20190409', '20190410', '20190411', '20190412', '20190413', '20190414', '20190415', '20190416', '20190417', '20190418', '20190419', '20190420', '20190421', '20190422', '20190423', '20190424', '20190425', '20190426', '20190427', '20190428', '20190429', '20190430', '20190502', '20190503', '20190504', '20190505', '20190506', '20190508', '20190509', '20190510', '20190511', '20190512', '20190513', '20190514', '20190515', '20190516', '20190517', '20190518', '20190519', '20190520', '20190521', '20190522', '20190523', '20190524', '20190525', '20190526', '20190527', '20190528', '20190529', '20190530', '20190531']

# %%
import pandas as pd
import date_cal as dc 
df = pd.read_excel('C:/Users/tjoeun/Downloads/7. 데이터 활용 매뉴얼 - 방송정보메타데이타샘플.xls')
# 사용할 컬럼만 추출 
df2 = df.loc[:,['프로그램','방송일','상품명','품번']]
print(len(df2))

# final_df = pd.DataFrame(columns)
# rate = api.loc[:,'비율_x']
df2.loc[i,'상품명']
final_df = pd.DataFrame()
for i in range(len(df2)):
    keyword = df2.loc[i,'상품명']
    broadcast_date = df2.loc[i,'방송일']
    date = dc.convert_strtime(broadcast_date)
    enddate = dc.timeminus(date, 30)
    startdate = dc.timeminus(date, -30)
    api = search(keyword,startdate=startdate,enddate=enddate)
    rate = api.loc[:,'비율_x']
    
    final_df[keyword] = rate
    # print(keyword,broadcast_date,api)
  # print(keyword,broadcast_date,api)
    print(rate.loc[:,'비율_x'])
    
    break

final_df
# Out:
# 500
# missing_dates :['20190402', '20190403', '20190404', '20190405', '20190406', '20190407', '20190408', '20190410', '20190411', '20190412', '20190413', '20190414', '20190415', '20190416', '20190417', '20190418', '20190419', '20190420', '20190421', '20190422', '20190423', '20190424', '20190425', '20190426', '20190427', '20190428', '20190429', '20190430', '20190502', '20190503', '20190504', '20190505', '20190506', '20190507', '20190508', '20190509', '20190510', '20190511', '20190512', '20190513', '20190514', '20190515', '20190516', '20190517', '20190518', '20190519', '20190520', '20190521', '20190522', '20190523', '20190524', '20190525', '20190526', '20190527', '20190528', '20190529', '20190530', '20190531']
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-6-da3be4cfbc39> in <module>
#      22     # print(keyword,broadcast_date,api)
#      23   # print(keyword,broadcast_date,api)
# ---> 24     print(rate.loc[:,'비율_x'])
#      25
#      26     break
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1274
#    1275         # no multi-index, so validate all of the indexers
# -> 1276         self._has_valid_tuple(tup)
#    1277
#    1278         # ugly hack for GH #836
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     698         for i, k in enumerate(key):
#     699             if i >= self.ndim:
# --> 700                 raise IndexingError("Too many indexers")
#     701             try:
#     702                 self._validate_key(k, i)
#
# IndexingError: Too many indexers
